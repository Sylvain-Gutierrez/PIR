# %%
import numpy as np
import pandas as pd
import sklearn as sk
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_folder = Path("data/data_spikes")

file_to_open = data_folder / "E18KABaseline_B_Amp.dat"

df = pd.read_csv(file_to_open, sep = "\t", header = 0, index_col = 0)

df=df.astype(float)
df.info()

print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 647 entries, 1.0 to 647.0
# Data columns (total 10 columns):
# T[s]                  520 non-null float64
# 21-Height[microV]     521 non-null float64
# 31-Height[microV]     508 non-null float64
# 41-Height[microVV]    469 non-null float64
# 22-Height[microV]     455 non-null float64
# 32-Height[microV]     460 non-null float64
# 42-Height[microV]     489 non-null float64
# 23-Height[microV]     542 non-null float64
# 33-Height[microV]     497 non-null float64
# 43-Height[microV]     0 non-null float64
# dtypes: float64(10)
# memory usage: 55.6 KB
#        T[s]  21-Height[microV]  31-Height[microV]  41-Height[microVV]  \
# 1.0  11.932             13.523             15.341              13.182
# 2.0  13.977             15.455             13.523              12.159
# 3.0  30.114             58.750             53.636              17.386
# 4.0     NaN                NaN                NaN                 NaN
# ...

# %%
df.plot(figsize=(14, 8), marker = '.')

# %%
df.reset_index().plot.scatter(x = 'index', y = '21-Height[microV]', figsize=(14, 8), marker = '.')
